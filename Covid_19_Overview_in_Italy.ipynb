# %% [markdown]
# <a href="https://colab.research.google.com/github/eduardoscovino/Covid-19-Overview/blob/main/Covid_19_Overview_in_Italy.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Data Analysis of Covid-19 Overview in Brazil**
# *Made with ♥ by Eduardo Scovino*

# %% [markdown]
# Hi, guys! Now we are in 2022 and I don't believe in the existence of a human being in Western Civilization who doesn't know what the hell is Covid-19.
#
# Everybody here knows what are the most common symptoms and the rate of cure. By now, we have a huge percentage of the population which already got the immunization.
#
# <center><img alt="Colaboratory logo" width="50%" src="https://raw.githubusercontent.com/carlosfab/dsnp2/master/img/covid19.jpg"></center>
#
# Talking about data, we also know that the virus let us a tremendous amount of data to analyze. That's exactly the purpose of this notebook.
#
# I'm gonna try to focus on classical libs as matplotlib and seaborn, but there's room for some not so orthodox libs as well. As we are talking about a country, it's also a good idea to explore some ideas of geolocalization.
#
# In addition, we can make some comparisions as well with other countries of UE.
#
# Follow me with this dataset from https://github.com/owid/covid-19-data/tree/master/public/data 🤓
#
# Hope you like it and take care!

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
path = 'https://raw.githubusercontent.com/owid/covid-19-data/master/public/data/owid-covid-data.csv'
df = pd.read_csv(path)
df
# Out:
#        iso_code continent     location        date  total_cases  new_cases  \
# 0           AFG      Asia  Afghanistan  2020-02-24          5.0        5.0
# 1           AFG      Asia  Afghanistan  2020-02-25          5.0        0.0
# 2           AFG      Asia  Afghanistan  2020-02-26          5.0        0.0
# 3           AFG      Asia  Afghanistan  2020-02-27          5.0        0.0
# 4           AFG      Asia  Afghanistan  2020-02-28          5.0        0.0
# ...         ...       ...          ...         ...          ...        ...
# 204535      ZWE    Africa     Zimbabwe  2022-07-23     256246.0       29.0
# 204536      ZWE    Africa     Zimbabwe  2022-07-24     256254.0        8.0
# 204537      ZWE    Africa     Zimbabwe  2022-07-25     256270.0       16.0
# 204538      ZWE    Africa     Zimbabwe  2022-07-26     256284.0       14.0
# 204539      ZWE    Africa     Zimbabwe  2022-07-27     256315.0       31.0
#
# ...

# %%
df.columns
# Out:
# Index(['iso_code', 'continent', 'location', 'date', 'total_cases', 'new_cases',
#        'new_cases_smoothed', 'total_deaths', 'new_deaths',
#        'new_deaths_smoothed', 'total_cases_per_million',
#        'new_cases_per_million', 'new_cases_smoothed_per_million',
#        'total_deaths_per_million', 'new_deaths_per_million',
#        'new_deaths_smoothed_per_million', 'reproduction_rate', 'icu_patients',
#        'icu_patients_per_million', 'hosp_patients',
#        'hosp_patients_per_million', 'weekly_icu_admissions',
#        'weekly_icu_admissions_per_million', 'weekly_hosp_admissions',
#        'weekly_hosp_admissions_per_million', 'total_tests', 'new_tests',
#        'total_tests_per_thousand', 'new_tests_per_thousand',
#        'new_tests_smoothed', 'new_tests_smoothed_per_thousand',
#        'positive_rate', 'tests_per_case', 'tests_units', 'total_vaccinations',
#        'people_vaccinated', 'people_fully_vaccinated', 'total_boosters',
# ...
